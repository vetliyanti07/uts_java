// %% [markdown]
// ### Project UTS SI-S1
//
// 1. Rancang sebuah *Class* bangun ruang **PRISMA SEGITIGA** dengan kemampuan menghitung Volume dari bangun ruang tersebut.
// 2. Buatlah sebuah aplikasi untuk implementasi class dari *point no 1* dalam jupyter notebook ini
// 3. Lakukan rancang kompunen-kompunen yang dibutuhkan
// 4. Lakukan *Enskapsulasi* dari class pada *point no 1*
// 5. Berikan penjelasan dari kode yang anda buat (dalam notebook tersebut).
// 6. Lakukan Eksekusi / *Run* sebelum upload ke github.
//
// • **Upload File Notebook ini** (*.ipynb) ke folder github anda paling lambat pada saat jadwal UTS.

// %%
//Jawab 
1.Rancang sebuah Class bangun ruang PRISMA SEGITIGA dengan kemampuan menghitung Volume dari bangun ruang tersebut.
    
import java.util.Scanner;

public class Prisma_Segitiga {
public static void main (String args []) {
Scanner in=new Scanner(System.in);

System.out.println("Penghitungan volume, dan luas alas bangun Prisma segitiga");
System.out.print("Masukkan tinggi alas segitiga : ");
double TA =in.nextDouble();
System.out.print("Masukkan panjang alas segitiga : ");
double PA =in.nextDouble();
System.out.print("Masukkan tinggi prisma : ");
double T =in.nextDouble();

double L =(PA*TA) /2 ;
double V =(L*T);
System.out.println("Luas alas segitiga = " +L);
System.out.println("Volume Prisma = "+V);
}
}
import java.util.Scanner;

public class Prisma_Segitiga {
public static void main (String args []) {
Scanner in=new Scanner(System.in);

System.out.println("Penghitungan volume, dan luas alas bangun Prisma segitiga");
System.out.print("Masukkan tinggi alas segitiga : ");
double TA =in.nextDouble();
System.out.print("Masukkan panjang alas segitiga : ");
double PA =in.nextDouble();
System.out.print("Masukkan tinggi prisma : ");
double T =in.nextDouble();

double L =(PA*TA) /2 ;
double V =(L*T);
System.out.println("Luas alas segitiga = " +L);
System.out.println("Volume Prisma = "+V);
}
}

// %%
// jawab:
2. Buatlah sebuah aplikasi untuk implementasi class dari point no 1 dalam jupyter notebook ini
.#include "stdafx.h"
#include<iostream>
#include <conio.h>
using namespace std;
void prisma segitiga();
int _tmain(int argc, _TCHAR* argv[])
{
	char P,yn;
	do
	{
	cout<<"Silahkan Memilih Bangun Ruang"<<endl;
	cout<< "prisma segitiga"<<endl;
	cout<<" Pilih : ";
	cin>>P;

else if (P == '')
	Prisma segitiga();
else
		cout<<"Pilihan Anda tidak Valid"<<endl;
	
	cout<<"-----------------------------"<<endl<<endl;
	cout<<"Kembali ke Menu (Y/N)  : ";
	cin>>yn;
	cout<<"-----------------------------"<<endl<<endl;
	}
	while (yn == 'y' || yn == 'y'); 
	cout << " Terima Kasih";
	
	_getch();
	return 0;
}

}
void Prisma segitiga()
{
	float As,Bs,Cs,Ts,Tp,Vp,LPp;
	cout<<"-----------------------------"<<endl;
	cout<<"Menghitung Luas Alas Prisma"<<endl;
	cout<<"-----------------------------"<<endl<<endl;

	cout<<"Masukkan Nilai sisi alas prisma segitiga  :"<<endl;
	cout<<" Sisi A (Alas segitiga) = ";
	cin>>As;
	cout<<" Sisi B = ";
	cin>>Bs;
	cout<<" Sisi C = ";
	cin>>Cs;
	cout<<" Tinggi Alas Prisma (Segitiga) = ";
	cin>>Ts;
	cout<<"Masukkan Nilai Tinggi Prisma  :";
	cin>>Tp;
	LPp=As*Ts+(As+Bs+Cs*Tp);
	//Menghitung Volume Prisma
	Vp=0.5*As*Ts*Tp;
	cout<<"Luas Permukaan Prisma adalah        : "<<LPp<<endl;
	cout<<"Volume Prisma adalah                : "<<Vp<<endl;

// %%
//jawab:
3. Lakukan rancang kompunen-kompunen yang dibutuhkan
$this->load->view('komponen/header');?>
<div class="container">
    <div class="card" style="margin-top:10px">
        <h4 class="card-header">Welcome - P. Framework Kel 05</h4>
        <div class="card-body">
            <p class="lead">Bangun Ruang prisma segitiga</p>
        </div>
    </div>            
</div>
$this->load->view('komponen/footer'); ?>

// %%
//jawab:
4. Lakukan Enskapsulasi dari class pada point no 1
    public class PrismaSegitiga {
int panjang;
int lebar;
string warna;
public PrismaSegitiga (string w, int p, int l) {
panjang = p; lebar = l; warna = w;
}
public setWarna (string w) {
warna = w;
}
}

PrismaSegitiga sPink = new PrismaSegitiga (“pink”, 20,10);
PrismaSegitiga sPutih = new PrismaSegitiga (“putih”, 15,10);
PrismaSegitiga sOrange = new PrismaSegitiga (“orange”, 30,15);



public class PrismaSegitiga 
{ int panjang; int lebar; string warna; 
public PrismaSegitiga (string w, int p, int l) { panjang = p; lebar = l; warna = w; } 
public setWarna (string w) { warna = w; }
PrismaSegitiga sPink = new PrismaSegitiga (“pink”, 20,10);

// %%
//jawab:
5. penjelasan tentang program ini adalah yang pertama:
a. `merancang sebuah Class bangun ruang prisma segitiga dan k menghitung Volume dari bangun ruang prisma segitiga
b. membuat sebuah aplikasi untuk implementasi class prisma segitiga
c. melakukan  rancang kompunen-kompunen yang dibutuhkan dalam prisma segitiga
d. melakukan Enskapsulasi  dari class prisma segitiga
